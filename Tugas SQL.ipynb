# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ## 1. Prepare a list of offices sorted by country, state, city.

# %%
run("SELECT * FROM offices ORDER BY country, state, city")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %% [markdown]
# ## 2. How many employees are there in the company?

# %%
run("SELECT COUNT(*) as TotalEmployees FROM employees")
# Out:
#    COUNT(*)
# 0        23

# %% [markdown]
# ## 3. What is the total of payments received?

# %%
run("SELECT SUM(amount) as TotalPayment FROM payments")
# Out:
#    TotalPayment
# 0    8853839.23

# %% [markdown]
# ## 4. List the product lines that contain 'Cars'

# %%
run("SELECT * FROM productlines WHERE textDescription LIKE '%Cars%'")
# Out:
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1        Trains  Model trains are a rewarding hobby for enthusi...
#
#   htmlDescription image
# 0            None  None
# 1            None  None

# %% [markdown]
# ## 5. Report total payments for October 28, 2004

# %%
run("SELECT SUM(amount) as TotalPayment FROM payments WHERE paymentDate = '2004-10-28'")
# Out:
#    TotalPayment
# 0      47411.33

# %% [markdown]
# ## 6. Report those payments greater than $100.000

# %%
run("SELECT SUM(amount) as TotalPayment FROM payments WHERE amount > 100000")
# Out:
#    TotalPayment
# 0     555016.97

# %% [markdown]
# ## 7. List the products in each product line.

# %%
run("SELECT * FROM products ORDER BY productLine")
# Out:
#     productCode                                  productName  \
# 0      S10_1949                     1952 Alpine Renault 1300
# 1      S10_4757                          1972 Alfa Romeo GTA
# 2      S10_4962                       1962 LanciaA Delta 16V
# 3      S12_1099                            1968 Ford Mustang
# 4      S12_1108                            2001 Ferrari Enzo
# 5      S12_3148                           1969 Corvair Monza
# 6      S12_3380                           1968 Dodge Charger
# 7      S12_3891                             1969 Ford Falcon
# 8      S12_3990                      1970 Plymouth Hemi Cuda
# 9      S12_4675                           1969 Dodge Charger
# 10     S18_1129                              1993 Mazda RX-7
# 11     S18_1589                        1965 Aston Martin DB5
# 12     S18_1889                  1948 Porsche 356-A Roadster
# 13     S18_1984                             1995 Honda Civic
# ...

# %% [markdown]
# ## 8. How many products in each product line?

# %%
run("SELECT productLine, COUNT(productCode) as totalProducts FROM products GROUP BY productLine")
# Out:
#         productLine  totalProducts
# 0      Classic Cars             38
# 1       Motorcycles             13
# 2            Planes             12
# 3             Ships              9
# 4            Trains              3
# 5  Trucks and Buses             11
# 6      Vintage Cars             24

# %% [markdown]
# ## 9. What is the minimum payment received?

# %%
run("SELECT MIN(amount) as minPayment FROM payments")
# Out:
#    minPayment
# 0      615.45

# %% [markdown]
# ## 10. List all payments greater than twice the average payment

# %%
run("SELECT * FROM payments HAVING amount > (AVG(amount) * 2)")
# Out:
# Empty DataFrame
# Columns: [customerNumber, checkNumber, paymentDate, amount]
# Index: []

# %% [markdown]
# ## 11. What is the average percentage markup of the MSRP on buyPrice?

# %% [markdown]
# ## 12. How many distinct products does ClassicModels sell?

# %%
run("SELECT COUNT(DISTINCT *) as totalProducts FROM products")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1377             else:
# -> 1378                 cur.execute(*args)
#    1379             return cur
#
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /anaconda3/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 516         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
# ...

# %% [markdown]
# ## 13. Report the name and city of customers who don't have sales representatives?

# %%
run("SELECT customerName, city FROM customers WHERE salesRepEmployeeNumber iS NULL")
# Out:
#                       customerName              city
# 0               Havel & Zbyszek Co          Warszawa
# 1                Porto Imports Co.            Lisboa
# 2       Asian Shopping Network, Co         Singapore
# 3                  Natürlich Autos         Cunewalde
# 4                    ANG Resellers            Madrid
# 5         Messner Shopping Network         Frankfurt
# 6                Franken Gifts, Co           München
# 7                BG&E Collectables          Fribourg
# 8                 Schuyler Imports         Amsterdam
# 9                 Der Hund Imports            Berlin
# 10       Cramer Spezialitäten, Ltd       Brandenburg
# 11           Asian Treasures, Inc.              Cork
# 12            SAR Distributors, Co          Hatfield
# 13                 Kommission Auto           Münster
# 14          Lisboa Souveniers, Inc            Lisboa
# 15  Stuttgart Collectable Exchange         Stuttgart
# 16        Feuer Online Stores, Inc           Leipzig
# ...

# %% [markdown]
# ## 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the

# %%
run("SELECT CONCAT(firstName, ' ', lastName) as name FROM employees WHERE jobTitle LIKE '%VP%' OR jobTitle LIKE '%Manager%'")
# Out:
#                 name
# 0     Mary Patterson
# 1      Jeff Firrelli
# 2  William Patterson
# 3      Gerard Bondur
# 4        Anthony Bow

# %% [markdown]
# ## 15. employee's first name and last name into a single field for reporting.

# %%
run("SELECT CONCAT(firstName, ' ', lastName) FROM employees")
# Out:
#    CONCAT(firstName, ' ', lastName)
# 0                      Diane Murphy
# 1                    Mary Patterson
# 2                     Jeff Firrelli
# 3                 William Patterson
# 4                     Gerard Bondur
# 5                       Anthony Bow
# 6                   Leslie Jennings
# 7                   Leslie Thompson
# 8                    Julie Firrelli
# 9                   Steve Patterson
# 10                   Foon Yue Tseng
# 11                    George Vanauf
# 12                      Loui Bondur
# 13                 Gerard Hernandez
# 14                  Pamela Castillo
# 15                       Larry Bott
# 16                      Barry Jones
# 17                      Andy Fixter
# 18                      Peter Marsh
# 19                         Tom King
# 20                       Mami Nishi
# 21                     Yoshimi Kato
# 22                    Martin Gerard

# %% [markdown]
# # 16. Which orders have a value greater than $5,000?

# %%
run("SELECT * FROM orders LIMIT 1000")
# Out:
#      orderNumber   orderDate requiredDate shippedDate      status  \
# 0          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 1          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 2          10102  2003-01-10   2003-01-18  2003-01-14     Shipped
# 3          10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# 4          10104  2003-01-31   2003-02-09  2003-02-01     Shipped
# 5          10105  2003-02-11   2003-02-21  2003-02-12     Shipped
# 6          10106  2003-02-17   2003-02-24  2003-02-21     Shipped
# 7          10107  2003-02-24   2003-03-03  2003-02-26     Shipped
# 8          10108  2003-03-03   2003-03-12  2003-03-08     Shipped
# 9          10109  2003-03-10   2003-03-19  2003-03-11     Shipped
# 10         10110  2003-03-18   2003-03-24  2003-03-20     Shipped
# 11         10111  2003-03-25   2003-03-31  2003-03-30     Shipped
# 12         10112  2003-03-24   2003-04-03  2003-03-29     Shipped
# ...
